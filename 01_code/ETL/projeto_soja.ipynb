# %%
import os
import pandas as pd

# %%
diretorio = os.getcwd()

# %%
os.chdir(diretorio)

# %%
os.chdir('' + diretorio + '/bases/tabelas')
arquivos_tabela = os.listdir('' + diretorio + '/bases/tabelas')
num_arquivos = len(arquivos_tabela)

tabelas = {}

for x in range(0, num_arquivos):

    tabelas['' + arquivos_tabela[x].replace('.csv', '') + ''] = pd.read_csv(arquivos_tabela[x], delimiter=';', encoding='latin-1')

# %%
tabelas.keys()
# Out:
# dict_keys(['NCM', 'NCM_CGCE', 'NCM_CUCI', 'NCM_FAT_AGREG', 'NCM_ISIC', 'NCM_PPE', 'NCM_PPI', 'NCM_SH', 'NCM_SIIT', 'NCM_UNIDADE', 'UF', 'UF_MUN', 'URF', 'VIA'])

# %%
len(arquivos_tabela) == len(tabelas)
# Out:
# True

# %%
locals().update(tabelas)

# %%
NCM[NCM['CO_SH6'].isin(['120100', '120110', '120190'])].head()
# Out:
#         CO_NCM  CO_UNID  CO_SH6  CO_PPE  CO_PPI  CO_FAT_AGREG CO_CUCI_ITEM  \
# 1937  12010010       10  120100    1315    1315             1         2222
# 1938  12010090       21  120100    1315    1315             1         2222
# 1939  12011000       10  120110    1315    1315             1         2222
# 1940  12019000       21  120190    1315    1315             1         2222
#
#       CO_CGCE_N3  CO_SIIT CO_ISIC4  CO_EXP_SUBSET  \
# 1937         230     9000       01         1702.0
# 1938         210     9000       01         1702.0
# 1939         230     9000       01         1702.0
# 1940         210     9000       01         1702.0
#
#                                         NO_NCM_POR  \
# 1937                           Soja para semeadura
# 1938        Outros grãos de soja, mesmo triturados
# 1939         Soja, mesmo triturada, para semeadura
# 1940  Soja, mesmo triturada, exceto para semeadura
#
#                                             NO_NCM_ESP  \
# ...

# %%
NCM1 = NCM[['CO_NCM', 'NO_NCM_POR', 'NO_NCM_ESP', 'NO_NCM_ING']][NCM['CO_SH6'].isin(['120100', '120110', '120190'])]
NCM1
NCM2 = NCM[['CO_NCM', 'NO_NCM_POR', 'NO_NCM_ESP', 'NO_NCM_ING']][NCM['CO_SH6'].isin(['310100', '310290', '310390', '310490', '310510', '310520', '310551', '310559', '310560', '310590', '382490', '382499', '843240', '843242'])]
NCM2
# Out:
#          CO_NCM                                         NO_NCM_POR  \
# 147    38249914  Senduramicina sódica, da fabricação da sendura...
# 148    38249915  Maduramicina amônica, em solução alcoólica, da...
# 149    38249919  Outros produtos intermediários da fabricação d...
# 150    38249921  Ácidos graxos dimerizados; preparações contend...
# 151    38249922  Preparações contendo estearoilbenzoilmetano e ...
# 152    38249923  Preparações contendo triglicerídios dos ácidos...
# 153    38249924  Ésteres de álcoois graxos de C12 a C20 do ácid...
# 154    38249925  Misturas de ésteres dimetílicos dos ácidos adí...
# 155    38249929  Outros derivados de ácidos graxos industriais;...
# 156    38249931  Misturas e preparações para borracha ou plásti...
# 157    38249932  Misturas e preparações para borracha ou plásti...
# 158    38249933  Misturas e preparações para borracha ou plásti...
# 159    38249934         Outras misturas contendo polietilenoaminas
# ...

# %%
NCM[['CO_NCM', 'NO_NCM_POR', 'NO_NCM_ESP', 'NO_NCM_ING']][NCM['CO_SH6'].isin(['120100', '120110', '120190'])]
# Out:
#         CO_NCM                                    NO_NCM_POR  \
# 1937  12010010                           Soja para semeadura
# 1938  12010090        Outros grãos de soja, mesmo triturados
# 1939  12011000         Soja, mesmo triturada, para semeadura
# 1940  12019000  Soja, mesmo triturada, exceto para semeadura
#
#                                             NO_NCM_ESP  \
# 1937                                 Soja para siembra
# 1938        Otros granos de soja, incluso quebrantados
# 1939          Soja, incluso quebrantadas, para siembra
# 1940  Soja, incluso quebrantadas, excepto para siembra
#
#                                              NO_NCM_ING
# 1937                                 Soybean for sowing
# 1938                       Other soybeans, even crushed
# 1939       Soybeans, whether or not crushed, for sowing
# 1940  Soybeans, whether or not crushed, except for s...

# %%
ncm = NCM['CO_NCM'][NCM['CO_SH6'].isin(['120100', '120110', '120190'])].values
ncm = ncm.astype(object)
ncm

ncm1 = NCM['CO_NCM'][NCM['CO_SH6'].isin(['310100', '310290', '310390', '310490', '310510', '310520', '310551', '310559', '310560', '310590', '382490', '382499', '843240', '843242'])].values
ncm1 = ncm1.astype(object)
ncm1
# Out:
# array([38249914, 38249915, 38249919, 38249921, 38249922, 38249923,
#        38249924, 38249925, 38249929, 38249931, 38249932, 38249933,
#        38249934, 38249935, 38249936, 38249939, 38249941, 38249942,
#        38249943, 38249949, 38249951, 38249952, 38249953, 38249954,
#        38249959, 38249971, 38249972, 38249973, 38249974, 38249975,
#        38249976, 38249977, 38249978, 38249979, 38249981, 38249982,
#        38249983, 38249985, 38249911, 38249912, 38249913, 84324200,
#        38249986, 38249987, 38249988, 38249989, 31029000, 31039011,
#        38249041, 38249042, 38249043, 38249049, 38249051, 38249052,
#        38249053, 38249054, 38249059, 38249061, 38249062, 38249063,
#        38249071, 38249072, 38249073, 31039019, 31039090, 31049010,
#        31049090, 31051000, 31052000, 31055100, 31055900, 31056000,
#        38249011, 38249012, 38249013, 38249014, 38249015, 38249019,
#        38249021, 38249074, 38249075, 38249076, 38249077, 38249078,
# ...

# %%
NCM_CGCE.head()
# Out:
#    CO_CGCE_N3                                         NO_CGCE_N3  \
# 0         110  Bens de capital (exceto equipamentos de transp...
# 1         120              Equipamentos de transporte industrial
# 2         210  Alimentos e bebidas básicos, destinados princi...
# 3         220  Alimentos e bebidas elaborados, destinados pri...
# 4         230                        Insumos industriais básicos
#
#                                       NO_CGCE_N3_ING  \
# 0  Capital goods, except industrial transport equ...
# 1            Equipment for industrial transportation
# 2      Basic food and beverages, mainly for industry
# 3  Elaborated food and beverages, mainly for indu...
# 4                            Basic industrial inputs
#
#                                       NO_CGCE_N3_ESP  CO_CGCE_N2  \
# 0  Bienes de capital, excepto equipo de transport...          11
# 1                   Equipos de transporte industrial          12
# ...

# %%
NCM_CUCI[NCM_CUCI['CO_CUCI_ITEM'].isin(['2222'])].head()
# Out:
#     CO_CUCI_ITEM NO_CUCI_ITEM  \
# 371         2222         Soja
#
#                                       NO_CUCI_ITEM_ING  CO_CUCI_SUB  \
# 371  Milk & cream, concentrated/sweetened, in solid...         2222
#
#     NO_CUCI_SUB NO_CUCI_SUB_ING  CO_CUCI_POS  \
# 371        Soja      Soya beans          222
#
#                                            NO_CUCI_POS  \
# 371  Sementes e frutos oleaginosos, dos tipos utili...
#
#                                        NO_CUCI_POS_ING  CO_CUCI_CAP  \
# 371  Oil-seeds and oleaginous fruits of a kind used...           22
#
#                        NO_CUCI_CAP                  NO_CUCI_CAP_ING  \
# 371  Sementes e frutos oleaginosos  Oil-seeds and oleaginous fruits
#
#      CO_CUCI_SEC                                        NO_CUCI_SEC  \
# 371            2  MATERIAS EM BRUTO, NAO COMESTIVEIS, EXCETO COM...
#
#                              NO_CUCI_SEC_ING
# 371  CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS

# %%
NCM_FAT_AGREG.head()
# Out:
#    CO_FAT_AGREG                NO_FAT_AGREG            NO_FAT_AGREG_GP
# 0             1            PRODUTOS BASICOS           PRODUTOS BASICOS
# 1             2  PRODUTOS SEMIMANUFATURADOS  PRODUTOS INDUSTRIALIZADOS
# 2             3      PRODUTOS MANUFATURADOS  PRODUTOS INDUSTRIALIZADOS
# 3             4        TRANSACOES ESPECIAIS        OPERACOES ESPECIAIS
# 4             5            CONSUMO DE BORDO        OPERACOES ESPECIAIS

# %%
NCM_ISIC[NCM_ISIC['CO_ISIC4'].isin(['01'])].head()
# Out:
#   CO_ISIC4                NO_ISIC4 CO_ISIC4_GRUPO  \
# 0       01  AGRICULTURA E PECUÁRIA          01A03
#
#                                       NO_ISIC4_GRUPO CO_ISIC4_SECAO  \
# 0  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...              A
#
#                                       NO_ISIC4_SECAO
# 0  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...

# %%
NCM_PPE.head()
# Out:
#    CO_PPE                                    NO_PPE  \
# 0    1011                 ABACAXIS FRESCOS OU SECOS
# 1    1041  ARROZ EM GRAOS, INCLUSIVE ARROZ QUEBRADO
# 2    1051                          ALGODAO EM BRUTO
# 3    1052                          AMENDOIM EM GRAO
# 4    1055                                   AMIANTO
#
#                                  NO_PPE_MIN  \
# 0                 Abacaxis frescos ou secos
# 1  Arroz em grãos, inclusive arroz quebrado
# 2                          Algodão em bruto
# 3                          Amendoim em grão
# 4                                   Amianto
#
#                              NO_PPE_ING
# 0            PINEAPPLES, FRESH OR DRIED
# 1  RICE IN GRAIN, INCLUDING BROKEN RICE
# 2                            RAW COTTON
# 3                     PEANUTS, IN GRAIN
# 4                              ASBESTOS

# %%
#NCM_SH = pd.read_csv('NCM.csv', delimiter = ';', encoding = 'latin-1')
NCM_SH.head()
# Out:
#    CO_SH6                                         NO_SH6_POR  \
# 0   10110  Animais vivos das espécies cavalar, asinina e ...
# 1   10111                 Cavalos reprodutores, de raça pura
# 2   10119                              Outros cavalos, vivos
# 3   10120                            Asininos e muares vivos
# 4   10121                  Cavalos reprodutores de raça pura
#
#                                      NO_SH6_ESP  \
# 0  Caballos y asnos, reproductores de raza pura
# 1           Caballos reproductores de raza pura
# 2                         Demás caballos, vivos
# 3              Asnos, mulos y burdéganos, vivos
# 4    Caballos de raza selecta para reproducción
#
#                             NO_SH6_ING  CO_SH4  \
# 0  Pure-bred breeding horses and asses     101
# 1            Pure-bred breeding horses     101
# 2                    Other live horses     101
# 3      Asses, mules and hinnies (live)     101
# 4            Pure-bred breeding horses     101
#
# ...

# %%
NCM_SIIT[NCM_SIIT['CO_SIIT'] == 9000].head()
# Out:
#    CO_SIIT           NO_SIIT
# 4     9000  PRODUTOS N.C.I.T

# %%
NCM_UNIDADE[NCM_UNIDADE['CO_UNID'].isin([10, 21])].head()
# Out:
#     CO_UNID                   NO_UNID SG_UNID
# 0        10        QUILOGRAMA LIQUIDO   KGL
# 11       21  TONELADA METRICA LIQUIDA   TML

# %%
NCM_UNIDADE1 = NCM_UNIDADE[['CO_UNID', 'NO_UNID', 'SG_UNID']][NCM_UNIDADE['CO_UNID'].isin([10, 21])]
NCM_UNIDADE1
NCM_UNIDADE2 = NCM_UNIDADE[['CO_UNID', 'NO_UNID', 'SG_UNID']][NCM_UNIDADE['CO_UNID'].isin([10, 11])]
NCM_UNIDADE2
# Out:
#    CO_UNID             NO_UNID SG_UNID
# 0       10  QUILOGRAMA LIQUIDO   KGL
# 1       11    NUMERO (UNIDADE)   UNID.

# %%
ncm_unidade = NCM_UNIDADE['CO_UNID'][NCM_UNIDADE['CO_UNID'].isin([10, 21])].values
ncm_unidade = ncm_unidade.astype(object)
ncm_unidade
# Out:
# array([10, 21], dtype=object)

# %%
UF[UF['SG_UF'].isin(['MT'])]
# Out:
#     CO_UF SG_UF        NO_UF            NO_REGIAO
# 23     52    MT  Mato Grosso  REGIAO CENTRO OESTE

# %%
UF_MUN[UF_MUN['CO_MUN_GEO'].isin((5107925, 5107602, 5106224, 5105259, 5107875, 5107040))]
# Out:
#       CO_MUN_GEO              NO_MUN          NO_MUN_MIN SG_UF
# 4396     5105259  LUCAS DO RIO VERDE  Lucas do Rio Verde    MT
# 4411     5106224          NOVA MUTUM          Nova Mutum    MT
# 5446     5107040  PRIMAVERA DO LESTE  Primavera do Leste    MT
# 5460     5107602        RONDONOPOLIS        Rondonópolis    MT
# 5469     5107875             SAPEZAL             Sapezal    MT
# 5472     5107925             SORRISO             Sorriso    MT

# %%
URF[URF['CO_URF'].isin((817800, 917600, 917800))]
# Out:
#      CO_URF                        NO_URF
# 84   917600  0917600 - PORTO DE PARANAGUA
# 217  817800     0817800 - PORTO DE SANTOS
# 228  917800  0917800 - PORTO DE PARANAGUA

# %%
URF1 = URF[URF['CO_URF'].isin((817800, 917600, 917800))]
URF1
# Out:
#      CO_URF                        NO_URF
# 84   917600  0917600 - PORTO DE PARANAGUA
# 217  817800     0817800 - PORTO DE SANTOS
# 228  917800  0917800 - PORTO DE PARANAGUA

# %%
urf = URF['CO_URF'][URF['CO_URF'].isin((817800, 917600, 917800))].values
urf = urf.astype(object)
urf
# Out:
# array([917600, 817800, 917800], dtype=object)

# %%
VIA[VIA['CO_VIA'].isin((1, 99))]
# Out:
#    CO_VIA            NO_VIA
# 1      99  VIA DESCONHECIDA
# 3       1          MARITIMA

# %%
VIA1 = VIA[VIA['CO_VIA'].isin((1, 99))]

# %%
os.chdir('' + diretorio + '/bases/info/')
arquivos_info = os.listdir('' + diretorio + '/bases/info/')
num_arquivos_info = len(arquivos_info)

info = {}

for x in range(0, num_arquivos_info):

    info['' + arquivos_info[x].replace('.csv', '') + ''] = pd.read_csv(arquivos_info[x], delimiter=';', encoding='latin-1')

# %%
arquivos_info
# Out:
# ['EXP_2018.csv', 'EXP_COMPLETA.csv', 'IMP_2018.csv', 'IMP_COMPLETA.csv']

# %% [markdown]
# info['' + arquivos_info[x].replace('.csv', '') + ''] = pd.read_csv(arquivos_info[x], delimiter=';', encoding='latin-1')

# %% [markdown]
# info['' + arquivos_info[x].replace('.csv', '') + ''] = pd.read_csv(arquivos_info[x], delimiter=';', encoding='latin-1')

# %%
info.keys()
# Out:
# dict_keys(['EXP_2018', 'EXP_COMPLETA', 'IMP_2018', 'IMP_COMPLETA'])

# %%
len(info) == len(arquivos_info)
# Out:
# True

# %%
locals().update(info)

# %%
IMP_2018.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2018       1  29156019       10      249        SP       4  817700
# 1    2018       1  84672999       11      355        PR       1  917800
# 2    2018       1  87088000       11       23        PR       1  917800
# 3    2018       1  85444200       10      386        SP       1  817800
# 4    2018       1  84833090       11      249        PR       4  917900
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0         7           7     648
# 1       125         477   15271
# 2      9635       58559  325968
# 3      1845        1845   51272
# 4        16           4     205

# %%
IMP_2018_URF = IMP_2018[IMP_2018['CO_URF'].isin((urf))]
IMP_2018_URF.head()
# Out:
#     CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 1     2018       1  84672999       11      355        PR       1  917800
# 2     2018       1  87088000       11       23        PR       1  917800
# 3     2018       1  85444200       10      386        SP       1  817800
# 13    2018       9  25120000       10      493        PR       1  917800
# 18    2018      12  85333910       11      160        SP       1  817800
#
#     QT_ESTAT  KG_LIQUIDO  VL_FOB
# 1        125         477   15271
# 2       9635       58559  325968
# 3       1845        1845   51272
# 13     70075       70075   65823
# 18    100003         701    9349

# %%
#IMP_2018_FILT = IMP_2018[IMP_2018['CO_UNID'].isin((ncm_unidade)) & IMP_2018['CO_NCM'].isin((ncm)) & IMP_2018['CO_URF'].isin((urf))]

#IMP_2018_FILT = IMP_2018[IMP_2018['CO_UNID'].isin((ncm_unidade)) & IMP_2018['CO_NCM'].isin((ncm))]

IMP_2018_FILT = IMP_2018[IMP_2018['SG_UF_NCM'].isin(['MT'])]

IMP_2018_FILT.head()
# Out:
#       CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 482     2018       1  84835010       11      160        MT       1  917800
# 760     2018       1  82090019       10      160        MT       1  917800
# 2737    2018      10  84099116       11      160        MT       1  917800
# 2797    2018       9  38089329       10      160        MT       1  817800
# 3148    2018       5  84122900       11      249        MT       1  817800
#
#       QT_ESTAT  KG_LIQUIDO  VL_FOB
# 482         13          73     186
# 760       1156        1156   19597
# 2737        65          36      17
# 2797     57600       57600  526433
# 3148        14         139   10052

# %%
IMP_2018_FILT = IMP_2018[IMP_2018['CO_NCM'].isin((ncm1)) & IMP_2018['SG_UF_NCM'].isin(['MT']) & IMP_2018['CO_URF'].isin((urf))]

IMP_2018_FILT.head()
# Out:
#         CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 25637     2018      10  31055900       10      160        MT       1  917800
# 28715     2018       3  31055900       10      249        MT       1  817800
# 75833     2018       6  31055900       10      249        MT       1  917800
# 111406    2018      11  31059090       10      603        MT       1  917800
# 113850    2018       8  31059090       10      573        MT       1  917800
#
#         QT_ESTAT  KG_LIQUIDO    VL_FOB
# 25637    8999859     8999859   3067034
# 28715   29589297    29589297  10957787
# 75833   11000000    11000000   4192830
# 111406     23000       23000     92840
# 113850     48000       48000     57361

# %%
IMP_2018_FILT1 = IMP_2018_FILT
IMP_2018_FILT1 = IMP_2018_FILT1.merge(NCM2, how='left', left_on=['CO_NCM'], right_on=['CO_NCM'])
IMP_2018_FILT1 = IMP_2018_FILT1.merge(NCM_UNIDADE2, how='left', left_on=['CO_UNID'], right_on=['CO_UNID'])
IMP_2018_FILT1 = IMP_2018_FILT1.merge(VIA1, how='left', left_on=['CO_VIA'], right_on=['CO_VIA'])
IMP_2018_FILT1 = IMP_2018_FILT1.merge(URF1, how='left', left_on=['CO_URF'], right_on=['CO_URF'])

# %%
IMP_2018_FILT1.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2018      10  31055900       10      160        MT       1  917800
# 1    2018       3  31055900       10      249        MT       1  817800
# 2    2018       6  31055900       10      249        MT       1  917800
# 3    2018      11  31059090       10      603        MT       1  917800
# 4    2018       8  31059090       10      573        MT       1  917800
#
#    QT_ESTAT  KG_LIQUIDO    VL_FOB  \
# 0   8999859     8999859   3067034
# 1  29589297    29589297  10957787
# 2  11000000    11000000   4192830
# 3     23000       23000     92840
# 4     48000       48000     57361
#
#                                           NO_NCM_POR  \
# 0  Outros adubos/fertilizantes minerais químicos,...
# 1  Outros adubos/fertilizantes minerais químicos,...
# 2  Outros adubos/fertilizantes minerais químicos,...
# 3  Outros adubos/fertilizantes minerais químicos ...
# ...

# %%
IMP_2018_FILT1.to_csv('' + diretorio + '/IMP_2018_FILT_DESC.csv', sep = ';', encoding = 'latin-1', decimal = ',', index = False)

# %%
EXP_2018_FILT = EXP_2018[EXP_2018['SG_UF_NCM'].isin(['MT'])]

EXP_2018_FILT.head()

# %%
EXP_2018.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2018      11  40169300       10      275        RJ      99   717700
# 1    2018       2   4089900       10      399        SP      99   817600
# 2    2018      11  94032000       11      845        SC      99  1017701
# 3    2018       3  87089481       11      169        SP       4   817700
# 4    2018       9  40093210       10      198        SP      99   817600
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0         0           0       5
# 1         5           5      10
# 2        12         238     485
# 3         4          11     208
# 4        26          26     602

# %%
#EXP_2018_FILT = EXP_2018[EXP_2018['CO_NCM'].isin((ncm)) & EXP_2018['CO_UNID'].isin((ncm_unidade)) & EXP_2018['SG_UF_NCM'].isin(['MT']) & EXP_2018['CO_URF'].isin((urf))]
EXP_2018_FILT = EXP_2018[EXP_2018['CO_NCM'].isin((ncm)) & EXP_2018['SG_UF_NCM'].isin(['MT']) & EXP_2018['CO_URF'].isin((urf))]

EXP_2018_FILT.head()
# Out:
#        CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 887      2018       4  12019000       21      858        MT       1  817800
# 10208    2018       4  12019000       21      160        MT       1  817800
# 16458    2018       9  12019000       21      160        MT      99  817800
# 26087    2018       6  12019000       21      455        MT       1  817800
# 26539    2018       4  12019000       21      576        MT       1  917800
#
#         QT_ESTAT  KG_LIQUIDO     VL_FOB
# 887      7507251    14750950    5910243
# 10208  146202314   715583542  284391568
# 16458      31676    31675949   11891415
# 26087       4340     4340000    1754230
# 26539        101      101227      43239

# %%
EXP_2018_FILT.to_csv('' + diretorio + '/EXP_2018_FILT.csv', sep = ';', encoding = 'latin-1', decimal = ',', index = False)

# %%
EXP_2018_FILT1 = EXP_2018_FILT

# %%
EXP_2018_FILT1 = EXP_2018_FILT1.merge(NCM1, how='left', left_on=['CO_NCM'], right_on=['CO_NCM'])

# %%
EXP_2018_FILT1 = EXP_2018_FILT1.merge(NCM_UNIDADE1, how='left', left_on=['CO_UNID'], right_on=['CO_UNID'])

# %%
EXP_2018_FILT1 = EXP_2018_FILT1.merge(VIA1, how='left', left_on=['CO_VIA'], right_on=['CO_VIA'])

# %%
EXP_2018_FILT1 = EXP_2018_FILT1.merge(URF1, how='left', left_on=['CO_URF'], right_on=['CO_URF'])

# %%
EXP_2018_FILT1.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2018       4  12019000       21      858        MT       1  817800
# 1    2018       4  12019000       21      160        MT       1  817800
# 2    2018       9  12019000       21      160        MT      99  817800
# 3    2018       6  12019000       21      455        MT       1  817800
# 4    2018       4  12019000       21      576        MT       1  917800
#
#     QT_ESTAT  KG_LIQUIDO     VL_FOB  \
# 0    7507251    14750950    5910243
# 1  146202314   715583542  284391568
# 2      31676    31675949   11891415
# 3       4340     4340000    1754230
# 4        101      101227      43239
#
#                                      NO_NCM_POR  \
# 0  Soja, mesmo triturada, exceto para semeadura
# 1  Soja, mesmo triturada, exceto para semeadura
# 2  Soja, mesmo triturada, exceto para semeadura
# 3  Soja, mesmo triturada, exceto para semeadura
# 4  Soja, mesmo triturada, exceto para semeadura
#
# ...

# %%
EXP_2018_FILT1.to_csv('' + diretorio + '/EXP_2018_FILT_DESC.csv', sep = ';', encoding = 'latin-1', decimal = ',', index = False)

# %%
EXP_COMPLETA.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    1997       3  41043911       15      149        RS       1  1010500
# 1    1997       5  63019000       10       97        MG       7   145200
# 2    1997       6  87168000       11      586        RS       7   145300
# 3    1997       8  39162000       10      249        SP       1   817800
# 4    1997       2  73130000       10       63        SP       7  1010900
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0      3987        4150   16725
# 1         0        1002    8420
# 2        48         153     915
# 3         0         138     586
# 4         0        2714    1972

# %%
EXP_COMPLETA_FILT = EXP_COMPLETA[EXP_COMPLETA['CO_NCM'].isin((ncm)) & EXP_COMPLETA['SG_UF_NCM'].isin(['MT']) & EXP_COMPLETA['CO_URF'].isin((urf))]

EXP_COMPLETA_FILT.head()
# Out:
#         CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 21527     1997       4  12010090       21      245        MT       1  817800
# 32356     1997       7  12010090       21      399        MT       1  817800
# 46801     1997       4  12010090       21       23        MT       1  817800
# 67054     1997       5  12010090       21      573        MT       1  817800
# 136252    1997       8  12010090       21       23        MT       1  817800
#
#         QT_ESTAT  KG_LIQUIDO   VL_FOB
# 21527       8339     8338680  2584991
# 32356       1251     1251000   399920
# 46801      11550    11550000  3285314
# 67054       2174     2174000   684723
# 136252      6300     6300000  1856400

# %%
len(EXP_COMPLETA_FILT)
# Out:
# 1702

# %%
EXP_COMPLETA_FILT.to_csv('' + diretorio + '/EXP_COMPLETA_FILT.csv', sep = ';', encoding = 'latin-1', decimal = ',', index = False)

# %%
EXP_COMPLETA_FILT1 = EXP_COMPLETA_FILT
EXP_COMPLETA_FILT1 = EXP_COMPLETA_FILT1.merge(NCM1, how='left', left_on=['CO_NCM'], right_on=['CO_NCM'])
EXP_COMPLETA_FILT1 = EXP_COMPLETA_FILT1.merge(NCM_UNIDADE1, how='left', left_on=['CO_UNID'], right_on=['CO_UNID'])
EXP_COMPLETA_FILT1 = EXP_COMPLETA_FILT1.merge(VIA1, how='left', left_on=['CO_VIA'], right_on=['CO_VIA'])
EXP_COMPLETA_FILT1 = EXP_COMPLETA_FILT1.merge(URF1, how='left', left_on=['CO_URF'], right_on=['CO_URF'])

# %%
EXP_COMPLETA_FILT1.to_csv('' + diretorio + '/EXP_COMPLETA_FILT_DESC.csv', sep = ';', encoding = 'latin-1', decimal = ',', index = False)
